# %% [markdown]
# # <center>Week 2 Assignment</center>
#
# ## Part 1
#
# As suggested in Use Case 1 of the FTE, we need to read the other nine stock files and insert their data into the database. While nine files isn't an undue burden to manually read, we are going to look ahead to the time when we may have 100 log files to read and implement this code using the DRY Principle. DRY stands for
#
# * Don't
# * Repeat
# * Yourself
#
# So, while we could create an individual cell to read each stock file, for this assignment, do it in one. I'll give you some help to get started.
#
#
# <hr>
#
# _Reference:_ <br>
# https://en.wikipedia.org/wiki/Don%27t_repeat_yourself

# %% [markdown]
# Much of computer science and programming is about identifying and exploiting patterns. In this case, we know there is a pattern to how the files are named, and we know (through inspection) that there is a pattern to the columns of data inside.
#
# The file names all start with a year, from 2009 straight to 2019 with no breaks:
#
# ```
# 2009_aapl_data.xlsx
# 2010_aapl_data.xlsx
# 2011_aapl_data.xlsx
# 2012_aapl_data.xlsx
# 2013_aapl_data.xlsx
# 2014_aapl_data.xlsx
# 2015_aapl_data.xlsx
# 2016_aapl_data.xlsx
# 2017_aapl_data.xlsx
# 2018_aapl_data.xlsx
# 2019_aapl_data.xlsx
# ```
#
# Do we know of anything in Python capable of generating a **range** of numbers like that?

# %%
for x in range(2009, 2020):
    print(x)
# Out:
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019

# %% [markdown]
# That should be enough to get you going. Feel free to use code and helper functions from the FTE. I gave you the .ipynb file for a reason :).
#
# Remember,
#
# * If you ran the FTE code, it will have already read in 2009 and created the database file.
# * If you start at 2009, depending on the condition above, you may need to handle the table already existing.
#
# It is your choice whether or not to use the dataset library. As with many things in life, there are tradeoffs -- some things are easier, some not.
#
# **Deliverable:**
#
# When you are done, you will have a database table with slightly more than 2500 rows in it. **Show this by doing a query that counts rows in the table.**

# %%
#import all needed libraries
import dataset
from openpyxl import load_workbook

# %%
#create variable names for data ingestion
input_name = '_aapl_data.xlsx'
db_file = 'gb_stock_prices.db'
db = dataset.connect("sqlite:///" + db_file)

# %%
if (len(db.tables) > 0):
    for table in db.tables:
        db[table].drop()

# %%
table = db.create_table("aapl")

# %%
def isfloat(value):
  try:
    float(value)
    return True
  except ValueError:
    return False

# Note: These have to be tested in the right order. isfloat() reports True for integers.
def get_type(value):
    if value.isdigit():
        return dataset.types.Integer
    elif isfloat(value):
        return dataset.types.Float
    elif '/' in value:
        return dataset.types.Date
    else:
        return dataset.types.Unicode

# %%
# Get column data formats
year = '2009'
data_file = "C:/Users/eltac/Desktop/data/" + year + input_name
workbook = load_workbook(filename=data_file)
sheet = workbook.active
header = sheet[1]
row2= sheet[2]
for index, col_name in enumerate(header):
    table.create_column(col_name.value, get_type(row2[index].value))

# %%
table.columns
# Out:
# ['id', 'date', 'close', 'volume', 'open', 'high', 'low']

# %%
from datetime import datetime,date
keys = table.columns[1:]
for x in range(2009, 2020):
    year=str(x)
    excel_file = "C:/Users/eltac/Desktop/data/"+year+input_name
    workbook = load_workbook(filename=excel_file)
    sheet = workbook.active
    print(excel_file)
    for values in list(sheet.values)[1:]:
        row = []
        row.append(datetime.strptime(values[0],'%Y/%m/%d').date())
        row = row + list(values[1:])
        d_row = dict(zip(keys,row))
        table.insert(d_row)
        print(year+input_name+' '+str(d_row)+" Inserted")
# Out:
# C:/Users/eltac/Desktop/data/2009_aapl_data.xlsx
# 2009_aapl_data.xlsx {'date': datetime.date(2009,
} Inserted
# 2009_aapl_data.xlsx {'date': datetime.date(2009, 9, 14), 'close': '24.8171', 'volume': '80383404.0000', 'open': '24.4043', 'high': '24.8428', 'low': '24.3214'} Inserted
# 2009_aapl_data.xlsx {'date': datetime.date(2009, 9, 11), 'close': '24.5943', 'volume': '87108026.0000', 'open': '24.7014', 'high': '24.7400', 'low': '24.4100'} Inserted
# 2009_aapl_data.xlsx {'date': datetime.date(2009, 9, 10), 'close': '24.6514', 'volume': '122612107.0000', 'open': '24.5800', 'high': '24.7500', 'low': '24.4014'} Inserted
# 2009_aapl_data.xlsx {'date': datetime.date(2009, 9, 9), 'close': '24.4486', 'volume': '202624511.0000', 'open': '24.6828', 'high': '24.9243', 'low': '24.2428'} Inserted
# 2009_aapl_data.xlsx {'date': datetime.date(2009, 9, 8), 'close': '24.7043', 'volume': '78524974.0000', 'open': '24.7114', 'high': '24.7343', 'low': '24.5714'} Inserted
# 2009_aapl_data.xlsx {'date': datetime.date(2009, 9, 4), 'close': '24.3300', 'volume': '93309888.0000', 'open': '23.8966', 'high': '24.3857', 'low': '23.8700'} Inserted
# C:/Users/eltac/Desktop/data/2010_aapl_data.xlsx
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 31), 'close': '46.0800', 'volume': '48344906.0000', 'open': '46.1357', 'high': '46.2114', 'low': '45.9014'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 30), 'close': '46.2371', 'volume': '39354103.0000', 'open': '46.4971', 'high': '46.5014', 'low': '46.1500'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 29), 'close': '46.4700', 'volume': '40775656.0000', 'open': '46.6028', 'high': '46.6357', 'low': '46.4428'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 28), 'close': '46.4957', 'volume': '43898371.0000', 'open': '46.5586', 'high': '46.6657', 'low': '46.4371'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 27), 'close': '46.3828', 'volume': '62274056.0000', 'open': '46.1217', 'high': '46.4914', 'low': '45.9314'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 23), 'close': '46.2286', 'volume': '55731469.0000', 'open': '46.4286', 'high': '46.4500', 'low': '46.1671'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 22), 'close': '46.4514', 'volume': '66449697.0000', 'open': '46.3371', 'high': '46.5314', 'low': '46.2214'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 21), 'close': '46.3150', 'volume': '63928793.0000', 'open': '46.1428', 'high': '46.3414', 'low': '46.0071'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 20), 'close': '46.0300', 'volume': '96006079.0000', 'open': '45.9428', 'high': '46.1786', 'low': '45.4614'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 17), 'close': '45.8014', 'volume': '96587849.0000', 'open': '45.9471', 'high': '45.9700', 'low': '45.7471'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 16), 'close': '45.8928', 'volume': '80244454.0000', 'open': '45.8700', 'high': '46.0871', 'low': '45.7286'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 15), 'close': '45.7657', 'volume': '103780771.0000', 'open': '45.7143', 'high': '46.1428', 'low': '45.5986'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 14), 'close': '45.7557', 'volume': '87718986.0000', 'open': '45.9614', 'high': '46.0771', 'low': '45.5714'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 13), 'close': '45.9528', 'volume': '109673093.0000', 'open': '46.3386', 'high': '46.4371', 'low': '45.8571'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 10), 'close': '45.7943', 'volume': '65576594.0000', 'open': '45.6643', 'high': '45.8643', 'low': '45.5143'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 9), 'close': '45.6796', 'volume': '73378782.0000', 'open': '46.0188', 'high': '46.0714', 'low': '45.5743'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 8), 'close': '45.8586', 'volume': '80165284.0000', 'open': '45.6614', 'high': '45.8600', 'low': '45.3014'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 7), 'close': '45.4586', 'volume': '97437439.0000', 'open': '46.2571', 'high': '46.2843', 'low': '45.4457'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010, 12, 6), 'close': '45.7357', 'volume': '111165143.0000', 'open': '45.5200', 'high': '46.0471', 'low': '45.4886'} Inserted
# 2010_aapl_data.xlsx {'date': datetime.date(2010,
} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 3, 1), 'close': '174.9700', 'volume': '25737560.0000', 'open': '174.2800', 'high': '175.1500', 'low': '172.8900'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 28), 'close': '173.1500', 'volume': '27953810.0000', 'open': '174.3200', 'high': '174.9100', 'low': '172.9200'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 27), 'close': '174.8700', 'volume': '27817640.0000', 'open': '173.2100', 'high': '175.0000', 'low': '172.7300'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 26), 'close': '174.3300', 'volume': '16991610.0000', 'open': '173.7100', 'high': '175.3000', 'low': '173.1732'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 25), 'close': '174.2300', 'volume': '21846400.0000', 'open': '174.1600', 'high': '175.8700', 'low': '173.9500'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 22), 'close': '172.9700', 'volume': '18890250.0000', 'open': '171.5800', 'high': '173.0000', 'low': '171.3800'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 21), 'close': '171.0600', 'volume': '17154540.0000', 'open': '171.8000', 'high': '172.3700', 'low': '170.3000'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 20), 'close': '172.0300', 'volume': '25323890.0000', 'open': '171.1900', 'high': '173.3200', 'low': '170.9900'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 19), 'close': '170.9300', 'volume': '18958570.0000', 'open': '169.7100', 'high': '171.4400', 'low': '169.4900'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 15), 'close': '170.4200', 'volume': '24603320.0000', 'open': '171.2500', 'high': '171.7000', 'low': '169.7500'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 14), 'close': '170.8000', 'volume': '21785180.0000', 'open': '169.7100', 'high': '171.2615', 'low': '169.3800'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 13), 'close': '170.1800', 'volume': '22389660.0000', 'open': '171.3900', 'high': '172.4800', 'low': '169.9200'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 12), 'close': '170.8900', 'volume': '22224400.0000', 'open': '170.1000', 'high': '171.0000', 'low': '169.7000'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 11), 'close': '169.4300', 'volume': '20940020.0000', 'open': '171.0500', 'high': '171.2100', 'low': '169.2500'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 8), 'close': '170.4100', 'volume': '23793830.0000', 'open': '168.9900', 'high': '170.6600', 'low': '168.4200'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 7), 'close': '170.9400', 'volume': '31644240.0000', 'open': '172.4000', 'high': '173.9400', 'low': '170.3400'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 6), 'close': '174.2400', 'volume': '28204640.0000', 'open': '174.6500', 'high': '175.5700', 'low': '172.8531'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 5), 'close': '174.1800', 'volume': '36054570.0000', 'open': '172.8600', 'high': '175.0800', 'low': '172.3501'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 4), 'close': '171.2500', 'volume': '31384720.0000', 'open': '167.4100', 'high': '171.6550', 'low': '167.2800'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 2, 1), 'close': '166.5200', 'volume': '32644590.0000', 'open': '166.9600', 'high': '168.9800', 'low': '165.9300'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 31), 'close': '166.4400', 'volume': '40613260.0000', 'open': '166.1100', 'high': '169.0000', 'low': '164.5600'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 30), 'close': '165.2500', 'volume': '60800480.0000', 'open': '163.2500', 'high': '166.1500', 'low': '160.2300'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 29), 'close': '154.6800', 'volume': '39914850.0000', 'open': '156.2500', 'high': '158.1300', 'low': '154.1100'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 28), 'close': '156.3000', 'volume': '26147280.0000', 'open': '155.7900', 'high': '156.3300', 'low': '153.6600'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 25), 'close': '157.7600', 'volume': '33508960.0000', 'open': '155.4800', 'high': '158.1300', 'low': '154.3200'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 24), 'close': '152.7000', 'volume': '25418110.0000', 'open': '154.1100', 'high': '154.4800', 'low': '151.7400'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 23), 'close': '153.9200', 'volume': '23046560.0000', 'open': '154.1500', 'high': '155.1400', 'low': '151.7000'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 22), 'close': '153.3000', 'volume': '30273990.0000', 'open': '156.4100', 'high': '156.7300', 'low': '152.6200'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 18), 'close': '156.8200', 'volume': '33259460.0000', 'open': '157.5000', 'high': '157.8800', 'low': '155.9806'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 17), 'close': '155.8600', 'volume': '29616190.0000', 'open': '154.2000', 'high': '157.6600', 'low': '153.2600'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 16), 'close': '154.9400', 'volume': '30483120.0000', 'open': '153.0800', 'high': '155.8800', 'low': '153.0000'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 15), 'close': '153.0700', 'volume': '28449940.0000', 'open': '150.2700', 'high': '153.3900', 'low': '150.0500'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 14), 'close': '150.0000', 'volume': '32018540.0000', 'open': '150.8500', 'high': '151.2700', 'low': '149.2200'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 11), 'close': '152.2900', 'volume': '26924630.0000', 'open': '152.8800', 'high': '153.7000', 'low': '151.5100'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 10), 'close': '153.8000', 'volume': '35661200.0000', 'open': '152.5000', 'high': '153.9700', 'low': '150.8600'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 9), 'close': '153.3100', 'volume': '45034370.0000', 'open': '151.2900', 'high': '154.5300', 'low': '149.6300'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 8), 'close': '150.7500', 'volume': '40622910.0000', 'open': '149.5600', 'high': '151.8200', 'low': '148.5200'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 7), 'close': '147.9300', 'volume': '54571440.0000', 'open': '148.7000', 'high': '148.8300', 'low': '145.9000'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 4), 'close': '148.2600', 'volume': '57423650.0000', 'open': '144.5300', 'high': '148.5499', 'low': '143.8000'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 3), 'close': '142.1900', 'volume': '91106840.0000', 'open': '143.9800', 'high': '145.7200', 'low': '142.0000'} Inserted
# 2019_aapl_data.xlsx {'date': datetime.date(2019, 1, 2), 'close': '157.9200', 'volume': '35637070.0000', 'open': '154.8900', 'high': '158.8500', 'low': '154.2300'} Inserted

# %%
print(f'Rows in worksheet (plus header): {len(sheet["A"])}' )
print(f'Rows in database: {len(table)}')
# Out:
# Rows in worksheet (plus header): 171
# Rows in database: 2516

# %% [markdown]
# ## Part 2
#
# Now that you have a working database with a reasonable amount of data in it, do some queries with it and show the data:
#
# 1. Find all days where the stock closed lower than 25.
#     * Print a count of how many
#     * Print the first 5 rows found
# 2. Find all days in 2017 where the stock closed above 35.
#     * Print a count of how many
#     * Print the last 5 found.
#
# **Deliverable:**
#
# 3. Create a new workbook and put each query result on a new worksheet in the workbook. Remember to save it to disk.

# %%
import sqlite3

# %%
import dataset
db = dataset.connect("sqlite:///gb_stock_prices.db")

# %%
for row in db.query('SELECT COUNT(*) AS TOTAL FROM aapl where close<25 '):
    
    print(row)
# Out:
# OrderedDict([('TOTAL', 6)])

# %%
from openpyxl import Workbook
from openpyxl.chart import BarChart, Reference

workbook = Workbook() # Create a new workbook
sheet = workbook.active = workbook.create_sheet("Q1 Part 1") # Get the active worksheet
header=[]
header.append('TOTAL')
excel_rows=[]
sheet.append(header)
for row in db.query('SELECT COUNT(*) AS TOTAL FROM aapl where close<25 '):
    excel_rows.append(row['TOTAL'])
    print(excel_rows)
    sheet.append(excel_rows)
# Out:
# [6]

# %%
high_close = db['aapl'].find(close = {'<': 25}, order_by='date',_limit=5)
excel_rows2 = []

# Get the headers
# excel_rows.append(db['aapl'].columns[1:])

for row in high_close:
    vals = [v for k, v in row.items()]
    excel_rows2.append(vals[1:])

excel_rows2[:]
# Out:
# [[datetime.date(2009, 9, 4), 24.33, 93309888.0, 23.8966, 24.3857, 23.87],
#  [datetime.date(2009, 9, 8), 24.7043, 78524974.0, 24.7114, 24.7343, 24.5714],
#  [datetime.date(2009, 9, 9), 24.4486, 202624511.0, 24.6828, 24.9243, 24.2428],
#  [datetime.date(2009, 9, 10), 24.6514, 122612107.0, 24.58, 24.75, 24.4014],
#  [datetime.date(2009, 9, 11), 24.5943, 87108026.0, 24.7014, 24.74, 24.41]]

# %%
sheet = workbook.active = workbook.create_sheet("Q1 Part 2") # Get the active worksheet

header = db['aapl'].columns[1:]
# The header row comes from the db as a weird type
# so we convert to string
header = [str(v) for v in header]
sheet.append(header)
for row in excel_rows2:
    sheet.append(row)

# %%
for row in db.query("SELECT count(*) AS TOTAL FROM aapl WHERE date between'2017-01-01' AND '2017-12-31' and close >35 "):
    
    print(row)
# Out:
# OrderedDict([('TOTAL', 251)])

# %%
sheet = workbook.active = workbook.create_sheet("Q2 Part 1") # Get the active worksheet
header=[]
header.append('TOTAL')
excel_rows3=[]
sheet.append(header)
for row in db.query("SELECT count(*) AS TOTAL FROM aapl WHERE date between'2016-12-31' AND '2017-12-31' and close >35 "):
    excel_rows3.append(row['TOTAL'])
    print(excel_rows3)
    sheet.append(excel_rows3)
# Out:
# [251]

# %%
high_close = db['aapl'].find(close = {'>': 35}, date={'between':['2017-01-01','2017-12-31']}, order_by='-date',_limit=5)
excel_rows4 = []

# Get the headers
# excel_rows.append(db['aapl'].columns[1:])

for row in high_close:
    vals = [v for k, v in row.items()]
    excel_rows4.append(vals[1:])

excel_rows4[:]
# Out:
# [[datetime.date(2017, 12, 29), 169.23, 25938760.0, 170.52, 170.59, 169.22],
#  [datetime.date(2017, 12, 28), 171.08, 16412270.0, 171.0, 171.85, 170.48],
#  [datetime.date(2017, 12, 27), 170.6, 21477380.0, 170.1, 170.78, 169.71],
#  [datetime.date(2017, 12, 26), 170.57, 33113340.0, 170.8, 171.47, 169.679],
#  [datetime.date(2017, 12, 22), 175.01, 16339690.0, 174.68, 175.424, 174.5]]

# %%
 # Get the active worksheet
sheet = workbook.active = workbook.create_sheet("Q2 Part 2")
header = db['aapl'].columns[1:]
# The header row comes from the db as a weird type
# so we convert to string
header = [str(v) for v in header]
sheet.append(header)
for row in excel_rows4:
    sheet.append(row)

# %%
fname = "gbernal_Week2_Assgn.xlsx"

workbook.save(filename=fname)

# %%
from openpyxl import load_workbook
workbook = load_workbook(filename="C:/Users/eltac/Downloads/gbernal_Week2_Assgn.xlsx")
Test=workbook.sheetnames
# Out:
# ['Sheet', 'Q1 Part 1', 'Q1 Part 2', 'Q2 Part 1', 'Q2 Part 2']
